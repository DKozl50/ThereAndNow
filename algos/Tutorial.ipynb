# %%
import pandas as pd
import numpy as np
import os

from tqdm import tqdm_notebook

import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Reshape, Conv2D, Conv2DTranspose, UpSampling2D
from tensorflow.keras.layers import LeakyReLU, Dropout, ReLU, BatchNormalization, InputLayer, Concatenate
from tensorflow.keras.optimizers import Adam, RMSprop

# %% [markdown]
# ## API usage

# %%
import fict_api4 as fapi

# %%
env = fapi.Environment()
# Out:
# Generating time_to_planes dataset...
# Generating country_to_hotels dataset...
# Done

# %% [markdown]
# To run example of using env use the code below

# %%
time1 = pd.to_datetime('28/8/2020')
time2 = pd.to_datetime('29/8/2020')

env.get_hotels(4, time1, time2)
# Out:
# Empty DataFrame
# Columns: [name, day_price, available_from, available_to, x, y]
# Index: []

# %%
env.get_tickets(time1, time2)
# Out:
# Empty DataFrame
# Columns: [price, from, to]
# Index: []

# %% [markdown]
# ## NN usage

# %%
import prediction

net = prediction.NN(True)

full_predict = net.G.predict(net.user_data.values.astype('float32'))
# Out:
# Data imported...
# Weights loaded

# %% [markdown]
# ## Parser Usage

# %%
cities_ = pd.read_csv('cities.csv')

# %%
df = net.user_data.copy()

# %%
df['target'] = full_predict[:, -1]

# %%
df
# Out:
#          SMS_IN_CNT_M3_mean  SMS_IN_CNT_M3_std  TRIP_DURATION_mean  \
# User_ID
# 80000            299.000000           1.154701               4.500
# 80001            395.050000         143.792788               4.650
# 80002            164.500000          28.991378               7.000
# 80003            249.666667          63.006878               5.500
# 80004            438.625000         109.247998               3.625
# ...                     ...                ...                 ...
# 180448           176.000000           0.000000               4.000
# 180449             0.000000           0.000000               0.000
# 180450             0.000000           0.000000              11.000
# 180451             0.000000           0.000000              13.000
# 180452            70.000000           0.000000               0.000
#
#          TRIP_DURATION_std  MOU_IN_REVENUE_M3_mean  MOU_IN_REVENUE_M3_std  \
# User_ID
# 80000             1.290994              532.116667              78.731334
# 80001             4.749238              250.322501             107.936626
# 80002             8.485281               84.649999              19.963982
# 80003             4.929503              822.913890             417.014447
# 80004             4.274091              295.881251              82.766410
# ...                    ...                     ...                    ...
# 180448            0.000000              173.050002               0.000000
# 180449            0.000000                0.000000               0.000000
# 180450            0.000000                0.000000               0.000000
# 180451            0.000000                0.000000               0.000000
# 180452            0.000000              225.050000               0.000000
#
#          MOU_OUT_REVENUE_M3_mean  MOU_OUT_REVENUE_M3_std  \
# User_ID
# 80000                 466.699996               67.222821
# 80001                 301.601666               79.642260
# 80002                  78.641666               15.026017
# 80003                 628.141667              537.880583
# 80004                 353.275002              118.160949
# ...                          ...                     ...
# 180448                280.716670                0.000000
# 180449                  0.000000                0.000000
# 180450                  0.000000                0.000000
# 180451                  0.000000                0.000000
# 180452                224.416668                0.000000
#
#          DOU_DURATION_M3_mean  DOU_DURATION_M3_std  ...    548    336    862  \
# User_ID                                             ...
# 80000             5381.978539          1291.962179  ...  False  False  False
# 80001             1857.871891          1692.410125  ...  False  False  False
# 80002             8816.631841          3352.524450  ...  False  False  False
# 80003             3695.561045           843.805226  ...  False  False  False
# 80004             2520.610484           962.627535  ...  False  False  False
# ...                       ...                  ...  ...    ...    ...    ...
# 180448            1273.079104             0.000000  ...  False  False  False
# 180449               0.000000             0.000000  ...  False  False  False
# 180450               0.000000             0.000000  ...  False  False  False
# 180451               0.000000             0.000000  ...  False  False  False
# 180452            1720.324223             0.000000  ...  False  False  False
#
#            704    876    732    887    894    716      target
# User_ID
# 80000    False  False  False  False  False  False  162.611221
# 80001    False  False  False  False  False  False  221.555069
# 80002    False  False  False  False  False  False  197.675171
# 80003    False  False  False  False  False  False  322.103485
# 80004    False  False  False  False  False  False  184.362793
# ...        ...    ...    ...    ...    ...    ...         ...
# 180448   False  False  False  False  False  False  209.140411
# 180449   False  False  False  False  False  False  148.776703
# 180450   False  False  False  False  False  False   42.530090
# 180451   False  False  False  False  False  False  152.927689
# 180452   False  False  False  False  False  False  192.226761
#
# [100453 rows x 266 columns]

# %%
net.user_data.join(full_predict[:, -1:])
# Out:
# ------------------------------------------------------------------
# AttributeError                   Traceback (most recent call last)
# <ipython-input-21-a2c7344673f5> in <module>
# ----> 1 net.user_data.join(full_predict[:, -1:])
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7259         # For SparseDataFrame's benefit
#    7260         return self._join_compat(
# -> 7261             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7262         )
#    7263
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7292             frames = [self] + list(other)
#    7293
# -> 7294             can_concat = all(df.index.is_unique for df in frames)
#    7295
#    7296             # join indexes only using concat
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in <genexpr>(.0)
#    7292             frames = [self] + list(other)
#    7293
# -> 7294             can_concat = all(df.index.is_unique for df in frames)
#    7295
#    7296             # join indexes only using concat
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'
